# %% [markdown]
# # Data Transformation I
#
# Next, we will begin transforming our dataset by dropping values. Our primary goal of this process is to:
#
# * drop rows with missing data
# * drop select columns with overwhelmingly missing data
#
# Utilize the documentation provided in each code-block. When you are done with this section of the project, validate that your output matches the screenshot provided in the `docs/part2.md` file.

# %%
import pandas as pd
import numpy as np

# %%
# TODO: load `data/raw/shopping.csv` as a pandas dataframe

df = pd.read_csv("/Users/alex/Desktop/TKH /TKH Projects/shopping-behavior/data/raw/shopping.csv")
df
# Out:
#       Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  \
# 0            3475   NaN    Male         Jacket              30.904467
# 1            3698  21.0  Female       Backpack              31.588259
# 2            2756  31.0    Male       Leggings              24.231704
# 3            3340   NaN    Male        Pajamas              33.918834
# 4            3391  38.0    Male     Sunglasses              36.545487
# ...           ...   ...     ...            ...                    ...
# 3895          147  43.0  Female     Sunglasses              61.610602
# 3896         1472  37.0    Male        Pajamas              44.600556
# 3897         1069   NaN  Female        Handbag              41.781965
# 3898         1171  39.0    Male         Hoodie              45.343778
# 3899          478  21.0  Female         Gloves              49.439181
#
#           Location Size         Color  Season  Review Rating   Shipping Type  \
# 0            Maine    M  Burnt orange    Fall            4.0        Standard
# 1              NaN    L     Turquoise  Winter            2.0         Express
# 2           Nevada    M   Terra cotta  Winter            4.0        Standard
# 3         Nebraska    M         Black  Winter            NaN        Standard
# 4           Oregon    S     Aubergine  Summer            NaN        Standard
# ...            ...  ...           ...     ...            ...             ...
# 3895      Colorado    S  Burnt orange    Fall            NaN  2-Day Shipping
# 3896        Alaska    S     Aubergine  Winter            4.0  2-Day Shipping
# 3897       Wyoming    M       Fuchsia  Summer            NaN        Standard
# 3898      Illinois    S     Brick red    Fall            NaN  2-Day Shipping
# 3899  North Dakota    M     Aubergine  Winter            4.0  2-Day Shipping
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 0                 No                   0    Credit Card                    NaN
# 1                 No                   1    Credit Card                Monthly
# 2                 No                   0    Credit Card                    NaN
# 3                 No                   2    Credit Card              Bi-Weekly
# 4                 No                   0    Credit Card                    NaN
# ...              ...                 ...            ...                    ...
# 3895             Yes                   7          Venmo                    NaN
# 3896             Yes                  20          Venmo                    NaN
# 3897             Yes                  13          Venmo                    NaN
# 3898             Yes                   3          Venmo                    NaN
# 3899             Yes                   2          Venmo                    NaN
#
# [3900 rows x 15 columns]

# %%
# TODO: print out the shape of this dataframe for better clarity
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html

df.shape
# Out:
# (3900, 15)

# %%
# TODO: display how many null values are in each column of this dataframe
# Documentation: https://datatofish.com/count-nan-pandas-dataframe/

df.isna().sum()
# Out:
# Customer ID                  0
# Age                        390
# Gender                       0
# Item Purchased               0
# Purchase Amount (USD)        0
# Location                   390
# Size                         0
# Color                        0
# Season                       0
# Review Rating             2469
# Shipping Type                0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases    2340
# dtype: int64

# %%
# TODO: it looks like there is roughly 65% of data missing "Frequency of Purchases". Drop this column, as it is mostly empty and unneeded for our analysis.
# In addition, also drop "Customer ID" as this column is also unnecessary
# Reassign this dropped dataframe as a new variable
# Documentation: drive.google.com/drive/folders/1pAWY1JqIQw26uhtT272AoDDeq7jtbkm2

new_df = df.drop(columns=["Frequency of Purchases", "Customer ID" ])

# %%
# TODO: print out the shape of this dataframe and verify that the shape is "(3900, 13)"

new_df.shape
# Out:
# (3900, 13)

# %%
# TODO: while "Review Rating" is also mostly empty, we are interested in figuring out why some users
# leave reviews and others don't. 

# Therefore we will NOT drop this column. Instead, let's reassign 
# all missing values in "Review Rating" with "Missing", and all non-na values as "Present"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html

#new_df['Review Rating'] = new_df["Review Rating"].fillna("Missing").replace({"Missing":"Present"})
new_review_rating = new_df["Review Rating"].fillna("Missing").replace([float(x) for x in range(0, 6, 1)], "Present")
new_df["Review Rating"] = new_review_rating
new_df.head(20)
# Out:
#      Age  Gender Item Purchased  Purchase Amount (USD)       Location Size  \
# 0    NaN    Male         Jacket              30.904467          Maine    M
# 1   21.0  Female       Backpack              31.588259            NaN    L
# 2   31.0    Male       Leggings              24.231704         Nevada    M
# 3    NaN    Male        Pajamas              33.918834       Nebraska    M
# 4   38.0    Male     Sunglasses              36.545487         Oregon    S
# 5   26.0    Male       Leggings              23.595139         Nevada   XL
# 6   43.0    Male          Dress              34.079015     California    M
# 7   29.0    Male         Shorts              23.796439      Minnesota    M
# 8   25.0  Female         Jacket              31.595005     Washington    M
# 9   39.0  Female         Shorts              32.374104       Colorado    M
# 10  45.0  Female         Jacket              35.548978        Florida    M
# 11  23.0    Male       Backpack              34.437918          Texas    M
# 12  27.0  Female        Handbag              29.430620       Virginia   XL
# 13  32.0  Female        Handbag              34.151352       Delaware    S
# 14   NaN    Male         Shorts              31.961771        Wyoming    L
# 15  22.0  Female        Pajamas              30.281125   North Dakota    L
# 16  41.0    Male        Sweater              24.125612  New Hampshire    M
# 17  45.0    Male        Handbag              23.929249           Utah    L
# 18  34.0  Female  Running Shoes              33.052216       Kentucky    S
# 19   NaN  Female       Leggings              30.550298       Michigan    M
#
#            Color  Season Review Rating Shipping Type Promo Code Used  \
# 0   Burnt orange    Fall       Present      Standard              No
# 1      Turquoise  Winter       Present       Express              No
# 2    Terra cotta  Winter       Present      Standard              No
# 3          Black  Winter       Missing      Standard              No
# 4      Aubergine  Summer       Missing      Standard              No
# 5          Brown  Winter       Missing      Standard              No
# 6    Terra cotta    Fall       Present      Standard              No
# 7       Lavender  Summer       Present       Express              No
# 8          Mauve    Fall       Present      Standard              No
# 9        Fuchsia  Summer       Missing      Standard              No
# 10         Brown  Winter       Missing      Standard              No
# 11         Brown  Winter       Missing      Standard              No
# 12         Black  Summer       Missing      Standard              No
# 13         White  Summer       Present      Standard              No
# 14    Pale peach  Spring       Missing       Express              No
# 15     Aubergine  Winter       Missing      Standard              No
# 16  Burnt orange  Winter       Missing      Standard              No
# 17       Fuchsia  Spring       Present      Standard              No
# 18       Fuchsia  Spring       Present      Standard              No
# 19  Burnt orange  Winter       Missing  Next Day Air              No
#
#     Previous Purchases Payment Method
# 0                    0    Credit Card
# 1                    1    Credit Card
# 2                    0    Credit Card
# 3                    2    Credit Card
# 4                    0    Credit Card
# 5                    3    Credit Card
# 6                    0    Credit Card
# 7                    0    Credit Card
# 8                    4    Credit Card
# 9                    3    Credit Card
# 10                  10    Credit Card
# 11                   2    Credit Card
# 12                   2    Credit Card
# 13                  11    Credit Card
# 14                   8    Credit Card
# 15                   3    Credit Card
# 16                   4    Credit Card
# 17                   3    Credit Card
# 18                   2    Credit Card
# 19                   6    Credit Card

# %%
new_df.head()
# Out:
#     Age  Gender Item Purchased  Purchase Amount (USD)  Location Size  \
# 0   NaN    Male         Jacket              30.904467     Maine    M
# 1  21.0  Female       Backpack              31.588259       NaN    L
# 2  31.0    Male       Leggings              24.231704    Nevada    M
# 3   NaN    Male        Pajamas              33.918834  Nebraska    M
# 4  38.0    Male     Sunglasses              36.545487    Oregon    S
#
#           Color  Season Review Rating Shipping Type Promo Code Used  \
# 0  Burnt orange    Fall       Present      Standard              No
# 1     Turquoise  Winter       Present       Express              No
# 2   Terra cotta  Winter       Present      Standard              No
# 3         Black  Winter       Missing      Standard              No
# 4     Aubergine  Summer       Missing      Standard              No
#
#    Previous Purchases Payment Method
# 0                   0    Credit Card
# 1                   1    Credit Card
# 2                   0    Credit Card
# 3                   2    Credit Card
# 4                   0    Credit Card

# %%
# TODO: Now that we've dropped and transformed our columns, drop the remaining rows that contain missing values
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

clean_df = new_df.dropna().dropna(axis = 'columns')

# %%
# TODO: display how many null values are in each column of this dataframe
# validate that each column has no missing values

clean_df.isna().sum()
# Out:
# Age                      0
# Gender                   0
# Item Purchased           0
# Purchase Amount (USD)    0
# Location                 0
# Size                     0
# Color                    0
# Season                   0
# Review Rating            0
# Shipping Type            0
# Promo Code Used          0
# Previous Purchases       0
# Payment Method           0
# dtype: int64

# %%
# TODO: print out the shape of this dataframe and verify that the shape is "(3158, 13)"

clean_df.shape
# Out:
# (3158, 13)

# %%
# TODO: print out the first 5 rows of this dataframe for validation

clean_df.head()
# Out:
#     Age Gender Item Purchased  Purchase Amount (USD)    Location Size  \
# 2  31.0   Male       Leggings              24.231704      Nevada    M
# 4  38.0   Male     Sunglasses              36.545487      Oregon    S
# 5  26.0   Male       Leggings              23.595139      Nevada   XL
# 6  43.0   Male          Dress              34.079015  California    M
# 7  29.0   Male         Shorts              23.796439   Minnesota    M
#
#          Color  Season Review Rating Shipping Type Promo Code Used  \
# 2  Terra cotta  Winter       Present      Standard              No
# 4    Aubergine  Summer       Missing      Standard              No
# 5        Brown  Winter       Missing      Standard              No
# 6  Terra cotta    Fall       Present      Standard              No
# 7     Lavender  Summer       Present       Express              No
#
#    Previous Purchases Payment Method
# 2                   0    Credit Card
# 4                   0    Credit Card
# 5                   3    Credit Card
# 6                   0    Credit Card
# 7                   0    Credit Card

# %%
# TODO: write this newly transformed dataset to the `data/processed` folder. Name it "shopping_cleaned.csv" 
# Be sure to not include an additional index when writing this csv file
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

clean_df.to_csv("/Users/alex/Desktop/TKH /TKH Projects/shopping-behavior/data/processed/shopping_cleaned.csv")
clean_df
# Out:
#        Age  Gender Item Purchased  Purchase Amount (USD)      Location Size  \
# 2     31.0    Male       Leggings              24.231704        Nevada    M
# 4     38.0    Male     Sunglasses              36.545487        Oregon    S
# 5     26.0    Male       Leggings              23.595139        Nevada   XL
# 6     43.0    Male          Dress              34.079015    California    M
# 7     29.0    Male         Shorts              23.796439     Minnesota    M
# ...    ...     ...            ...                    ...           ...  ...
# 3894  39.0    Male  Running Shoes              55.636680        Kansas    L
# 3895  43.0  Female     Sunglasses              61.610602      Colorado    S
# 3896  37.0    Male        Pajamas              44.600556        Alaska    S
# 3898  39.0    Male         Hoodie              45.343778      Illinois    S
# 3899  21.0  Female         Gloves              49.439181  North Dakota    M
#
#              Color  Season Review Rating   Shipping Type Promo Code Used  \
# 2      Terra cotta  Winter       Present        Standard              No
# 4        Aubergine  Summer       Missing        Standard              No
# 5            Brown  Winter       Missing        Standard              No
# 6      Terra cotta    Fall       Present        Standard              No
# 7         Lavender  Summer       Present         Express              No
# ...            ...     ...           ...             ...             ...
# 3894         White  Summer       Missing  2-Day Shipping             Yes
# 3895  Burnt orange    Fall       Missing  2-Day Shipping             Yes
# 3896     Aubergine  Winter       Present  2-Day Shipping             Yes
# 3898     Brick red    Fall       Missing  2-Day Shipping             Yes
# 3899     Aubergine  Winter       Present  2-Day Shipping             Yes
#
#       Previous Purchases Payment Method
# 2                      0    Credit Card
# 4                      0    Credit Card
# 5                      3    Credit Card
# 6                      0    Credit Card
# 7                      0    Credit Card
# ...                  ...            ...
# 3894                  11          Venmo
# 3895                   7          Venmo
# 3896                  20          Venmo
# 3898                   3          Venmo
# 3899                   2          Venmo
#
# [3158 rows x 13 columns]
